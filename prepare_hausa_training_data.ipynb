# %%
from datasets import Dataset, DatasetDict, Audio, concatenate_datasets
from IPython.display import Audio as DisplayAudio
import random

# %%
naijavoices_train_manifest = "/mnt/md0/synvoices/data/naijavoices/train_manifest_0h.jsonl"
naijavoices_dev_manifest = "/mnt/md0/synvoices/data/naijavoices/dev_manifest.jsonl"
naijavoices_test_manifest = "/mnt/md0/synvoices/data/naijavoices/test_manifest.jsonl"
synthetic_train_manifest = "/mnt/md0/synvoices/data/hausa_yourtts_asr_augmented/manifest_993h.jsonl"

# %%
# convert to a Hugging Face dataset
naijavoices_train = Dataset.from_json(naijavoices_train_manifest, split="train")
dev = Dataset.from_json(naijavoices_dev_manifest, split="validation")
test = Dataset.from_json(naijavoices_test_manifest, split="test")
synthetic_train = Dataset.from_json(synthetic_train_manifest, split="train")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
# rename 'audio_filepath' to 'audio'
naijavoices_train = naijavoices_train.rename_column('audio_filepath', 'audio')
synthetic_train = synthetic_train.rename_column('audio_filepath', 'audio')
dev = dev.rename_column('audio_filepath', 'audio')
test = test.rename_column('audio_filepath', 'audio')

# %%
# save the test set for convenience
# DatasetDict({"test": test}).save_to_disk("/mnt/md0/synvoices/data/hausa_naijavoices_test")

# %%
# remove unnecessary columns
cols = ['speaker_id', 'age_bracket', 'gender']
naijavoices_train = naijavoices_train.remove_columns(cols)
dev = dev.remove_columns(cols)
test = test.remove_columns(cols)

# %%
# # write all the transcripts to txt files
# def dump_transcripts(dataset, filename):
#     texts = dataset['text']
#     with open(filename, 'w') as f:
#         for text in texts:
#             f.write(f"{text}\n")
#     print(f"Transcripts saved to {filename}")

# %%
len(naijavoices_train), len(synthetic_train)
# Out:
# (19, 621398)

# %%
# concatenate training sets
# train = concatenate_datasets([naijavoices_train, synthetic_train])

# or use only naijavoices
train = naijavoices_train

# or use only synthetic
# train = synthetic_train

# shuffle the training set
train = train.shuffle(seed=42)

# %%
train[0]
# Out:
# {'text': 'ana iya rubutu da kowanne irin harshe idan har an koyeshi',
#  'audio': '/mnt/md0/synvoices/data/naijavoices/audio-unconverted/20240115140514-55-1810-312476-ana-iya-rubutu-da-kowanne-irin.wav',
#  'duration': 3.84}

# %%
# cast to audio
train = train.cast_column('audio', Audio(sampling_rate=16000))
dev = dev.cast_column('audio', Audio(sampling_rate=16000))
test = test.cast_column('audio', Audio(sampling_rate=16000))

# %%
train[0]
# Out:
# {'text': 'ana iya rubutu da kowanne irin harshe idan har an koyeshi',
#  'audio': {'path': '/mnt/md0/synvoices/data/naijavoices/audio-unconverted/20240115140514-55-1810-312476-ana-iya-rubutu-da-kowanne-irin.wav',
#   'array': array([ 0.        ,  0.        ,  0.        , ..., -0.02905273,
#           0.0687561 ,  0.02703857]),
#   'sampling_rate': 16000},
#  'duration': 3.84}

# %%
# listen to a random sample from the training set
sample = random.choice(train)
print(sample['text'])
DisplayAudio(sample['audio']['array'], rate=sample['audio']['sampling_rate'])
# Out:
# nera dari biyar ne
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
dataset_dict = DatasetDict({
    'train': train,
    'validation': dev,
    'test': test
})

# %%
train
# Out:
# Dataset({
#     features: ['text', 'audio', 'duration'],
#     num_rows: 19
# })

# %%
dev
# Out:
# Dataset({
#     features: ['text', 'audio', 'duration'],
#     num_rows: 4538
# })

# %%
# save to disk
dataset_dict.save_to_disk("/mnt/md0/synvoices/data/naijavoices_1m", num_proc=12)
# Out:
# Saving the dataset (0/12 shards):   0%|          | 0/19 [00:00<?, ? examples/s]
# Saving the dataset (0/12 shards):   0%|          | 0/4538 [00:00<?, ? examples/s]
# Saving the dataset (0/12 shards):   0%|          | 0/4524 [00:00<?, ? examples/s]

# %%
# from huggingface_hub import notebook_login
# notebook_login()

# %%
# upload to the hub
dataset_dict.push_to_hub("CLEAR-Global/naijavoices_1m")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/19 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/4538 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/46 [00:00<?, ?ba/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/4524 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/46 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/CLEAR-Global/naijavoices_1m/commit/0ace8ed0614dd9b9fd20c4f3a311095dc12ae553', commit_message='Upload dataset', commit_description='', oid='0ace8ed0614dd9b9fd20c4f3a311095dc12ae553', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/CLEAR-Global/naijavoices_1m', endpoint='https://huggingface.co', repo_type='dataset', repo_id='CLEAR-Global/naijavoices_1m'), pr_revision=None, pr_num=None)
